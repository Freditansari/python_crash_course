# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

from mpl_finance import candlestick_ohlc
from matplotlib.dates import MONDAY, DateFormatter, DayLocator, WeekdayLocator


# %matplotlib inline

# %%
import pandas_datareader.data as web
import datetime
start = datetime.datetime(2018,9,1)
end = datetime.datetime(2019,1,23)
stocks = 'FB AMZN AAPL NFLX GOOGL SQ ^IXIC'
stocks = stocks.split()
data = web.DataReader(stocks, 'yahoo', start, end )

# %%
fig = plt.figure(figsize=(16,7))
ax = fig.add_axes([0,0,1,1])

for stock in stocks:
    ax.plot(data['Close', stock], label =stock)

ax.legend(loc = 0 )

# %%
## transactions volume

volumesDF = pd.DataFrame()
fig = plt.figure(figsize=(16,7))
ax = fig.add_axes([0,0,1,1])

for stock in stocks:
    volumesDF[stock] = data['Open',stock] * data['Volume', stock]

for stock in stocks:
    ax.plot(volumesDF[stock], label =stock)

ax.legend(loc = 0 )

# %% [markdown]
# ## Daily Returns & Volatility

# %%
dailyReturnsDF = pd.DataFrame()


for stock in stocks:
    dailyReturnsDF[stock] = data['Close',stock].pct_change(1) 


# dailyReturnsDF['ERAA'] = data['Close','ERAA.JK'].pct_change(1)

# %%
for stock in stocks:
    dailyReturnsDF[stock].plot(kind='kde' , figsize = (20,8), label =stock)

# dailyReturnsDF['ERAA'].plot(kind='kde' , figsize = (20,8), label ='ERAA')


plt.legend()

# %%
##BOX CHARTS
dailyReturnsDF.plot(kind='box',figsize=(8,11),colormap='jet')

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(dailyReturnsDF, figsize=(16,16), alpha = 0.2, hist_kwds={'bins':100})
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f729d9100b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f729d93b6d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f729d8e1940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f729d888ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f729d8b0e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f729d85e0b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f729d805320>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f729d82b5c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f729d82b5f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f729d7f5a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f729d79ccc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f729d743f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f729d7731d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f729d717438>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f729d6bc6a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f729d6e5908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f729d68cb70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f729d6b1dd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f729d664080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f729d6072e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f729d62e550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f729d5d17b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f729db8a8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f729db807f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f729dbd9198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f729dd5fc18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f729dd2c2e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f729dd525c0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f729de3f438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f729defb8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f729dfc20b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f729dffafd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f729de9ccf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f729de59b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f729de9b0b8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f729debb630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f729dd51ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f729dfcc160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f729e03a6d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f729e01ec50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f729dee1208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f729dfaf780>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f729dc19198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f729dc132b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f729dc53828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f729de39da0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f729de0d358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f729dd9f8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f729dcb4e48>]],
#       dtype=object)

# %% [markdown]
# ## Cummulative returns

# %%
Cummulative = pd.DataFrame()

for stock in stocks:
    Cummulative[stock] = (1+dailyReturnsDF[stock]).cumprod()

# %%
fig = plt.figure(figsize=(16,7))

ax = fig.add_axes([0,0,1,1])

for stock in stocks:
    ax.plot(Cummulative[stock], label =stock)


ax.legend(loc = 0 )

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# ETS (Error Trend Seasonal ) analysis

# %%
result = seasonal_decompose(dailyReturnsDF['SQ'][1:], model ='additive', freq=7)

# %%
fig = plt.figure(figsize=(16,7))

fig = result.plot()

# %%
#nasdaq
result = seasonal_decompose(dailyReturnsDF['^IXIC'][1:], model ='additive', freq=7)
fig = plt.figure(figsize=(16,7))

fig = result.plot()
