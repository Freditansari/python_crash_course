# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np 
x = np.linspace(0,5,11)
y = x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
# Functional method 
plt.plot(x,y)
plt.xlabel('xlabel')
plt.ylabel('ylabel')
plt.title('title')
#plt.show() - if not using jupyter
# Out:
# Text(0.5, 1.0, 'title')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r')
plt.subplot(1,2,2)
plt.plot(y,x)

# %%
#oo mapplot lib

# %%
fig = plt.figure()
axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y)
axes.set_xlabel('x-label')
axes.set_ylabel('y-label')
axes.set_title('title')
# Out:
# Text(0.5, 1.0, 'title')

# %%
# fig = plt.figure()
# axes1= fig.add_axes([0.1,0.1,0.8,0.8])
# fig = plt.figure()
# axes1= fig.add_axes([0.1,0.1,0.8,0.8])
# axes2= fig.add_axes([0.2,0.5,0.4,0.3])
# #axes2= fig.add_axes([0.4,0.15,0.4,0.3])

# axes1.set_title('Larger plot')
# axes2.set_title('smaller plot')
# axes1.plot(x,y)
# axes2.plot(y,x,'R')

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
# axes.plot(x,y)
# plt.tight_layout()
# for current_ax in axes:
#     current_ax.plot(x,y)

# we can also do : 
axes[0].plot(x,y)
axes[0].set_title('potato distribution')
axes[1].plot(y,x)
axes[1].set_title('potato virus distribution')

plt.tight_layout()

# %%
potato_figure = plt.figure(figsize=(3,2), dpi = 100)
