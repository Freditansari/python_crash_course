# %%
import quandl
quandl.ApiConfig.api_key ="co-y5EAq-HFsEZZF9H4_"

# %%
mydata=quandl.get('EIA/PET_RWTC_D')

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline 
mydata.plot().set_title("oil prices")
# Out:
# Text(0.5, 1.0, 'oil prices')

# %%
sf_home_sales = quandl.get("ZILLOW/CO47_SALES", authtoken="co-y5EAq-HFsEZZF9H4_")

# %%
sf_home_sales[-20:].plot().set_title('SF- Home Sales')
# Out:
# Text(0.5, 1.0, 'SF- Home Sales')

# %%
AAPL = quandl.get("WIKI/AAPL", authtoken="co-y5EAq-HFsEZZF9H4_")
