# %%
import numpy as np
import pandas as pd 
import seaborn as sns
# %matplotlib inline 

import matplotlib.pyplot as plt
plt.style.use('ggplot')

df1 = pd.read_csv('df1', index_col=0)
df1.index = pd.to_datetime(df1.index)

# %%
df1.head()
# Out:
#                    A         B         C         D
# date
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2= pd.read_csv('df2')

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1['A'].hist(bins=30)

# %%
df1['A'].plot.hist()

# %%
df2.plot.bar(stacked='true')

# %%
df1['A'].plot.hist(bins=100)

# %%
df1.index
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08',
#                '2000-01-09', '2000-01-10',
#                ...
#                '2002-09-17', '2002-09-18', '2002-09-19', '2002-09-20',
#                '2002-09-21', '2002-09-22', '2002-09-23', '2002-09-24',
#                '2002-09-25', '2002-09-26'],
#               dtype='datetime64[ns]', name='date', length=1000, freq=None)

# %%
df1.index=pd.to_datetime(df1.index)
type(df1.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
df1.plot.line(y='B', figsize=(16,4), lw =0.5)

# %%
# df1.plot.scatter(x='A', y='B', c='C', figsize=(20,20), cmap='coolwarm')
df1.plot.scatter(x='A', y='B', s=df1['C']*100,figsize=(20,20))

# %%
df2.plot.box()

# %%
df = pd.DataFrame(np.random.randn(1000,2), columns =['a', 'b'])

# %%
df.plot.hexbin(x='a', y ='b', gridsize =25, figsize=(20,20), cmap='coolwarm')

# %%
# df2['a'].plot.kde()
df2.plot.kde(figsize=(20,20))
